# %%
print("Hii")
# Out:
# Hii

# %%
def hello():
    print("Hello, World!")

# %%
hello()
# Out:
# Hello, World!

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.5 MB 3.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/12.5 MB 4.0 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.5 MB 4.3 MB/s eta 0:00:03
#    ------------ --------------------------- 3.9/12.5 MB 4.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.0/12.5 MB 4.6 MB/s eta 0:00:02
#    -------------------- ------------------- 6.3/12.5 MB 4.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.5 MB 5.2 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.5 MB 5.2 MB/s eta 0:00:01
# ...
