# %%
import numpy as np
import pandas as pd
import plotly
import cufflinks
import plotly.express as px
import plotly.graph_objects as go

# %%
tips = sns.load_dataset('tips')
fig = px.line(tips,y='total_bill')
fig.show()

# %%
avg_tip = tips.groupby('day', observed=False)['tip'].mean().reset_index()
fig = px.bar(avg_tip,x='day',y='tip',title='Average Tip by Day')
fig.show()

# %%
s = tips.groupby('day', observed=False)['tip'].mean()
fig = go.Figure(data=[go.Bar(x=s.index,y=s.values)])
fig.show()

# %%
fig = px.scatter(tips,x='total_bill',y='tip',title='Tip vs Total Bill')
fig.show()

# %%
fig = px.box(tips,x='day',y='total_bill',title='Total Bill Distribution by Day')
fig.show()
