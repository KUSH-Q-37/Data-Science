# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
plt.plot(x,y)
plt.title('First Graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.subplot(2,2,1)
plt.plot(y,x)
plt.title('First')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.subplot(2,2,2)
plt.plot(x,y)
plt.title('Second')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.subplot(2,2,3) 
plt.plot(x,x)
plt.title('Third')
plt.xlabel('X axis')
plt.ylabel('Y axis') 
plt.subplot(2,2,4)
plt.plot(y,y**2)
plt.title('Forth')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.tight_layout()

# %% [markdown]
# Object Oriented way
#
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(20,8),dpi =100)
axis1 = fig.add_axes([0.1,0.1,.4,.8])
axis1.plot(x,y)
plt.title('Tiger')
axis2 = fig.add_axes([0.3,0.4,.3,.3])
axis2.plot(y,x)
plt.title('Lion')
# Out:
# Text(0.5, 1.0, 'Lion')

# %% [markdown]
# Types of Plot

# %%
plt.scatter(y,x)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 8.,  7., 15.,  7., 11.,  3., 10., 12., 14., 13.]),
#  array([  1. , 100.8, 200.6, 300.4, 400.2, 500. , 599.8, 699.6, 799.4,
#         899.2, 999. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x127e0340050>,
#   <matplotlib.lines.Line2D at 0x127e0340190>],
#  'caps': [<matplotlib.lines.Line2D at 0x127e03402d0>,
#   <matplotlib.lines.Line2D at 0x127e0340410>],
#  'boxes': [<matplotlib.lines.Line2D at 0x127e033bed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x127e0340550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x127e0340690>],
#  'means': []}

# %% [markdown]
# Saving Plots

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %% [markdown]
# Working with Images

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('images.jpeg')
img.shape
# Out:
# (678, 452, 3)

# %%
plt.imshow(img)

# %%
cropped_eye = img[210:250, 150:320]  # crop: rows 50-200, cols 100-300
plt.imshow(cropped_eye)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(169.5), np.float64(39.5), np.float64(-0.5))

# %% [markdown]
# Optional Designing

# %%
plt.plot(x,y,color = "red")

# %%
xaxis = np.linspace(0,5,11)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis, xaxis+5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green")
