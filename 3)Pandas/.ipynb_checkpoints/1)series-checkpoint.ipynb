# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
lables=['a','b','c']
l1=[10,20,30]
arr=np.array([10,20,30])
d={'a':10,'b':20,'c':30}

# %%
pd.Series(l1)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(l1,index=lables)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,index=lables)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
